# %%
import pandas as pd
import numpy as np
import os

pd.set_option('display.max_columns', None)

# %%
space_units_df = pd.read_csv('../data/scraped/space_units_df.csv')
ground_units_df= pd.read_csv('../data/scraped/ground_units_df.csv')

# %%
space_units_df['Is_Ship'] = True
space_units_df['Is_Ground_Force'] = False
ground_units_df['Is_Ship'] = False
ground_units_df['Is_Ground_Force'] = True

# %%
all_units_df = pd.concat([space_units_df, ground_units_df]).reset_index(drop=True)
all_units_df
# Out:
#                   Unit_Name           Faction_Name  \
# 0          Advanced Carrier  The Federation of Sol
# 1       Advanced Carrier II  The Federation of Sol
# 2             Airo Shir Rex            Radiant Aur
# 3              Arc Secundus   The Barony of Letnev
# 4                 Artemiris    The Council Keleres
# ..                      ...                    ...
# 99               Reanimator   The Vuil'Raith Cabal
# 100               Reclaimer              The Winnu
# 101               Indomitus      The Xxcha Kingdom
# 102           Moyin's ashes    The Yin Brotherhood
# 103  Blackshade Infiltrator     The Yssaril Tribes
#
#                                         Unit_Abilities  \
# 0                                                  NaN
# 1                                                  NaN
# 2    At the end of the edict phase, if this unit is...
# 3    Other players' units in this system lose PLANE...
# 4    Other players must spend 2 influence to activa...
# ..                                                 ...
# 99   When your infantry on this planet are destroye...
# 100  After you resolve a tactical action where you ...
# 101  You may use this unit's SPACE CANNON against s...
# 102  DEPLOY: When you use your INDOCTRINATION facti...
# 103  DEPLOY: After you use your STALL TACTICS facti...
#
#               Standard_Abilities  Has_Sustain_Damage Cost  Combat  \
# 0                            NaN               False    3       9
# 1                            NaN                True    3       9
# 2    Anti-Fighter Barrage 5 (x3)                True    8  7 (x2)
# 3             Bombardment 5 (x3)                True    8  5 (x2)
# 4                            NaN                True    8  7 (x2)
# ..                           ...                 ...  ...     ...
# 99                           NaN                True    2       6
# 100                          NaN                True    2       6
# 101               Space Cannon 8                True    2       6
# 102                          NaN                True    2       6
# 103                          NaN                True    2       6
#
#     Combat_Value  Shots Move Capacity Unit_Type  Is_Ship  Is_Ground_Force
# 0              9      1   1^       6^   Carrier     True            False
# 1              9      1    2        8   Carrier     True            False
# 2              7      2    1        6  Flagship     True            False
# 3              5      2    1        3  Flagship     True            False
# 4              7      2    1        6  Flagship     True            False
# ..           ...    ...  ...      ...       ...      ...              ...
# 99             6      1  NaN      NaN     Mechs    False             True
# 100            6      1  NaN      NaN     Mechs    False             True
# 101            6      1  NaN      NaN     Mechs    False             True
# 102            6      1  NaN      NaN     Mechs    False             True
# 103            6      1  NaN      NaN     Mechs    False             True
#
# [104 rows x 14 columns]

# %%
# Account for Upgrade Symbols
all_units_df['Cost_Value'] = all_units_df['Cost'].str.extract(r'(\d)').fillna(0).astype(int)
all_units_df['Move_Value'] = all_units_df['Move'].str.extract(r'(\d)').fillna(0).astype(int)
all_units_df['Capacity_Value'] = all_units_df['Capacity'].str.extract(r'(\d)').fillna(0).astype(int)

# %%
# Split 'Standard Abilities'

# ANTI-FIGHTER
all_units_df['Has_Anti_Fighter'] = all_units_df['Standard_Abilities'].str.contains('Anti-Fighter Barrage', na=False)
all_units_df[['Anti_Fighter_Value', 'Anti_Fighter_Shots']] = all_units_df['Standard_Abilities'].str.extract(
    r'\bAnti-Fighter Barrage\s*(\d+)?\s*\(x(\d+)\)?')

# BOMBARDMENT
all_units_df['Has_Bombardment'] = all_units_df['Standard_Abilities'].str.contains('Bombardment', na=False)
all_units_df[['Bombardment_Value', 'Bombardment_Shots']] = all_units_df['Standard_Abilities'].str.extract(
    r'\bBombardment\s*(\d+)?\s*\(x(\d+)\)?')

# SPACE CANNON
all_units_df['Has_Space_Cannon'] = all_units_df['Standard_Abilities'].str.contains('Space Cannon', na=False)
all_units_df[['Space_Cannon_Value', 'Space_Cannon_Shots']] = all_units_df['Standard_Abilities'].str.extract(
    r'\bSpace Cannon\s*(\d+)?\s*\(x(\d+)\)?')

# Set shots to 1 if ability present
all_units_df.loc[all_units_df['Has_Anti_Fighter'] & all_units_df['Anti_Fighter_Shots'].isna(), 'Anti_Fighter_Shots'] = 1
all_units_df.loc[all_units_df['Has_Bombardment'] & all_units_df['Bombardment_Shots'].isna(), 'Bombardment_Shots'] = 1
all_units_df.loc[all_units_df['Has_Space_Cannon'] & all_units_df['Space_Cannon_Shots'].isna(), 'Space_Cannon_Shots'] = 1

# Fill missing combat values with 0
all_units_df['Anti_Fighter_Value'] = all_units_df['Anti_Fighter_Value'].fillna(0)
all_units_df['Bombardment_Value'] = all_units_df['Bombardment_Value'].fillna(0)
all_units_df['Space_Cannon_Value'] = all_units_df['Space_Cannon_Value'].fillna(0)

# Fill missing shot values with 0
all_units_df['Anti_Fighter_Shots'] = all_units_df['Anti_Fighter_Shots'].fillna(0)
all_units_df['Bombardment_Shots'] = all_units_df['Bombardment_Shots'].fillna(0)
all_units_df['Space_Cannon_Shots'] = all_units_df['Space_Cannon_Shots'].fillna(0)

all_units_df.head(30)
# Out:
#                  Unit_Name                Faction_Name  \
# 0         Advanced Carrier       The Federation of Sol
# 1      Advanced Carrier II       The Federation of Sol
# 2            Airo Shir Rex                 Radiant Aur
# 3             Arc Secundus        The Barony of Letnev
# 4                Artemiris         The Council Keleres
# 5              Arvicon Rex   The Mahact Gene Sorcerers
# 6           C'Morran N'orr               Sardakk N'orr
# 7                  Carrier                 Common Unit
# 8               Carrier II                 Common Unit
# 9                  Cruiser                 Common Unit
# 10              Cruiser II                 Common Unit
# 11          D.W.S Luminous  The Deepwrought Scholarate
# 12               Destroyer                 Common Unit
# 13            Destroyer II                 Common Unit
# 14             Dreadnought                 Common Unit
# 15          Dreadnought II                 Common Unit
# 16           Duha Menaimon                 The Arborec
# 17                  Dynamo                The Empyrean
# 18                  Enigma               Il Na Viroset
# 19                 Exile I       The Crimson Rebellion
# 20                Exile II       The Crimson Rebellion
# 21              Exotrireme               Sardakk N'orr
# 22           Exotrireme II               Sardakk N'orr
# 23              Fighter II                 Common Unit
# 24             Fourth Moon        The Mentak Coalition
# 25                 Genesis       The Federation of Sol
# 26            Heaven's Eye               The Firmament
# 27         Heaven's Hollow                The Obsidian
# 28              Hil Colish        The Ghosts of Creuss
# 29  Hybrid Crystal Fighter        The Naalu Collective
#
#                                        Unit_Abilities  \
# 0                                                 NaN
# 1                                                 NaN
# 2   At the end of the edict phase, if this unit is...
# 3   Other players' units in this system lose PLANE...
# 4   Other players must spend 2 influence to activa...
# 5   During combat against an opponent whose comman...
# 6   Apply +1 to the result of each of your other s...
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11  This ship can move through systems that contai...
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15  "Direct Hit" cards are no longer effective aga...
# 16  After you activate this system, you may produc...
# 17  After any player's unit in this system or an a...
# 18  This unit ignores the effects of all anomalies...
# 19  At the end of any player's combat in this unit...
# 20  At the end of any player's combat in this unit...
# 21                                                NaN
# 22  After a round of space combat, you may destroy...
# 23  This unit may move without being transported. ...
# 24  Other players' ships in this system cannot use...
# 25  At the end of the status phase, place 1 infant...
# 26  If the Active System contains units that belon...
# 27                                                NaN
# 28  This ship's system contains a delta wormhole &...
# 29                                                NaN
#
#              Standard_Abilities  Has_Sustain_Damage    Cost  Combat  \
# 0                           NaN               False       3       9
# 1                           NaN                True       3       9
# 2   Anti-Fighter Barrage 5 (x3)                True       8  7 (x2)
# 3            Bombardment 5 (x3)                True       8  5 (x2)
# 4                           NaN                True       8  7 (x2)
# 5                           NaN                True       8  5 (x2)
# 6                           NaN                True       8  6 (x2)
# 7                           NaN               False       3       9
# 8                           NaN               False       3       9
# 9                           NaN               False       2      7^
# 10                          NaN               False       2       6
# 11                          NaN                True       8  7 (x2)
# 12  Anti-Fighter Barrage 9 (x2)               False       1      9^
# 13  Anti-Fighter Barrage 6 (x3)               False       1       8
# 14                Bombardment 5                True       4       5
# 15                Bombardment 5                True       4       5
# 16                          NaN                True       8  7 (x2)
# 17                          NaN                True       8  5 (x2)
# 18                          NaN                True       7       7
# 19  Anti-Fighter Barrage 9 (x2)               False       1      8^
# 20  Anti-Fighter Barrage 6 (x3)               False       1       7
# 21           Bombardment 4 (x2)                True       4       5
# 22           Bombardment 4 (x2)                True       4       5
# 23                          NaN               False  1 (x2)       8
# 24                          NaN                True       8  7 (x2)
# 25                          NaN                True       8  5 (x2)
# 26                          NaN                True       8  5 (x2)
# 27                          NaN                True       8  5 (x3)
# 28                          NaN                True       8       5
# 29                          NaN               False  1 (x2)      8^
#
#    Combat_Value  Shots Move Capacity    Unit_Type  Is_Ship  Is_Ground_Force  \
# 0             9      1   1^       6^      Carrier     True            False
# 1             9      1    2        8      Carrier     True            False
# 2             7      2    1        6     Flagship     True            False
# 3             5      2    1        3     Flagship     True            False
# 4             7      2    1        6     Flagship     True            False
# 5             5      2    1        3     Flagship     True            False
# 6             6      2    1        3     Flagship     True            False
# 7             9      1   1^       4^      Carrier     True            False
# 8             9      1    2        6      Carrier     True            False
# 9             7      1   2^       -^      Cruiser     True            False
# 10            6      1    3        1      Cruiser     True            False
# 11            7      2    1        6     Flagship     True            False
# 12            9      1    2        0    Destroyer     True            False
# 13            8      1    2        0    Destroyer     True            False
# 14            5      1   1^        1  Dreadnought     True            False
# 15            5      1    2        1  Dreadnought     True            False
# 16            7      2    1        5     Flagship     True            False
# 17            5      2    1        3     Flagship     True            False
# 18            7      1    7        7     Flagship     True            False
# 19            8      1    2        0    Destroyer     True            False
# 20            7      1    2        0    Destroyer     True            False
# 21            5      1   1^        1  Dreadnought     True            False
# 22            5      1    2        1  Dreadnought     True            False
# 23            8      1    2        0      Fighter     True            False
# 24            7      2    1        3     Flagship     True            False
# 25            5      2    1       12     Flagship     True            False
# 26            5      2    1        3     Flagship     True            False
# 27            5      3    1        3     Flagship     True            False
# 28            5      1    1        3     Flagship     True            False
# 29            8      1   -^        0      Fighter     True            False
#
#     Cost_Value  Move_Value  Capacity_Value  Has_Anti_Fighter  \
# 0            3           1               6             False
# 1            3           2               8             False
# 2            8           1               6              True
# 3            8           1               3             False
# 4            8           1               6             False
# 5            8           1               3             False
# 6            8           1               3             False
# 7            3           1               4             False
# 8            3           2               6             False
# 9            2           2               0             False
# 10           2           3               1             False
# 11           8           1               6             False
# 12           1           2               0              True
# 13           1           2               0              True
# 14           4           1               1             False
# 15           4           2               1             False
# 16           8           1               5             False
# 17           8           1               3             False
# 18           7           7               7             False
# 19           1           2               0              True
# 20           1           2               0              True
# 21           4           1               1             False
# 22           4           2               1             False
# 23           1           2               0             False
# 24           8           1               3             False
# 25           8           1               1             False
# 26           8           1               3             False
# 27           8           1               3             False
# 28           8           1               3             False
# 29           1           0               0             False
#
#    Anti_Fighter_Value Anti_Fighter_Shots  Has_Bombardment Bombardment_Value  \
# 0                   0                  0            False                 0
# 1                   0                  0            False                 0
# 2                   5                  3            False                 0
# 3                   0                  0             True                 5
# 4                   0                  0            False                 0
# 5                   0                  0            False                 0
# 6                   0                  0            False                 0
# 7                   0                  0            False                 0
# 8                   0                  0            False                 0
# 9                   0                  0            False                 0
# 10                  0                  0            False                 0
# 11                  0                  0            False                 0
# 12                  9                  2            False                 0
# 13                  6                  3            False                 0
# 14                  0                  0             True                 0
# 15                  0                  0             True                 0
# 16                  0                  0            False                 0
# 17                  0                  0            False                 0
# 18                  0                  0            False                 0
# 19                  9                  2            False                 0
# 20                  6                  3            False                 0
# 21                  0                  0             True                 4
# 22                  0                  0             True                 4
# 23                  0                  0            False                 0
# 24                  0                  0            False                 0
# 25                  0                  0            False                 0
# 26                  0                  0            False                 0
# 27                  0                  0            False                 0
# 28                  0                  0            False                 0
# 29                  0                  0            False                 0
#
#    Bombardment_Shots  Has_Space_Cannon Space_Cannon_Value Space_Cannon_Shots
# 0                  0             False                  0                  0
# 1                  0             False                  0                  0
# 2                  0             False                  0                  0
# 3                  3             False                  0                  0
# 4                  0             False                  0                  0
# 5                  0             False                  0                  0
# 6                  0             False                  0                  0
# 7                  0             False                  0                  0
# 8                  0             False                  0                  0
# 9                  0             False                  0                  0
# 10                 0             False                  0                  0
# 11                 0             False                  0                  0
# 12                 0             False                  0                  0
# 13                 0             False                  0                  0
# 14                 1             False                  0                  0
# 15                 1             False                  0                  0
# 16                 0             False                  0                  0
# 17                 0             False                  0                  0
# 18                 0             False                  0                  0
# 19                 0             False                  0                  0
# 20                 0             False                  0                  0
# 21                 2             False                  0                  0
# 22                 2             False                  0                  0
# 23                 0             False                  0                  0
# 24                 0             False                  0                  0
# 25                 0             False                  0                  0
# 26                 0             False                  0                  0
# 27                 0             False                  0                  0
# 28                 0             False                  0                  0
# 29                 0             False                  0                  0

# %%
if not os.path.exists('../data/clean'):
    os.makedirs('../data/clean')

all_units_df.to_csv('../data/clean/all_units_df.csv', index=False)
